# %% [markdown]
# # LETS GROW MORE

# %% [markdown]
# # Name : Purnanand Kulkarni
# ## Task : Image to Pencil Sketch

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\purnanand\anaconda3\lib\site-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\purnanand\anaconda3\lib\site-packages (from opencv-python) (1.20.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
from PIL import Image
from IPython.display import display

# %%
img = cv2.imread('F:\Puku\Photos\Google Photos Restored\Puku_Gaurang.jpg')

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
display(Image.fromarray(img))
# Out:
# <PIL.Image.Image image mode=RGB size=1080x676 at 0x207BD1896D0>

# %% [markdown]
# # Converting Image to GrayScale

# %%
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
display(Image.fromarray(gray_image))
# Out:
# <PIL.Image.Image image mode=L size=1080x676 at 0x207BD728DF0>

# %% [markdown]
# # Blur the image

# %%
inv_gray_image = 255 - gray_image
display(Image.fromarray(inv_gray_image))
# Out:
# <PIL.Image.Image image mode=L size=1080x676 at 0x207BD10EE50>

# %%
blur_image = cv2.GaussianBlur(inv_gray_image, (35, 35), 0)

# %%
display(Image.fromarray(blur_image))
# Out:
# <PIL.Image.Image image mode=L size=1080x676 at 0x207BD73A7C0>

# %%
inverted_blur_image = 255 - blur_image

# %% [markdown]
# # Pencil Sketch

# %%
pencil_sketch = cv2.divide(gray_image, inverted_blur_image, scale=256.0)

# %%
cv2.imshow("Sketch Image", pencil_sketch)
display(Image.fromarray(pencil_sketch))
# Out:
# <PIL.Image.Image image mode=L size=1080x676 at 0x207BD728760>

# %%
display(Image.fromarray(img))
display(Image.fromarray(pencil_sketch))
# Out:
# <PIL.Image.Image image mode=RGB size=1080x676 at 0x207BD728760>
# <PIL.Image.Image image mode=L size=1080x676 at 0x207BD73AE20>
