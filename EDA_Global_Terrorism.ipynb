# %% [markdown]
# # Name : Purnanand Kulkarni
# ## TASK 2  ( Level - Intermediate )
# ### EDA on Dataset Terrorism
# ### Dataset Link : https://bit.ly/2TK5Xn5

# %% [markdown]
# # Let's Grow More

# %% [markdown]
# # EDA Problem Statement
# * Perform 'Exploratory Data Analysis' on dataset 'Global Terrorism'
# * As a Security/Defence analyst, try to find out the hot zones of terrorism.
# * What all security issues and insites can you derive from EDA ?

# %% [markdown]
# ### 1. Import Data and Required libraries
# #### 1.1 Importing Numpy, Pandas, Seaborn and Matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### 1.2 Loading CSV file

# %%
df = pd.read_csv(r"globalterrorismdb_0718dist.csv")

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
df.tail()
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# ...

# %% [markdown]
# ### Understanding the Data

# %%
df.shape
# Out:
# (181691, 135)

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
df.dtypes
# Out:
# eventid        int64
# iyear          int64
# imonth         int64
# iday           int64
# approxdate    object
#                ...
# INT_LOG        int64
# INT_IDEO       int64
# INT_MISC       int64
# INT_ANY        int64
# related       object
# Length: 135, dtype: object

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %% [markdown]
# ### Renaming columns

# %%
df.rename(columns={'iyear':'Year', 'imonth':'Month', 'iday':'Day', 'country_txt':'Country', 'provstate':'State',
                  'region_txt':'Region', 'attacktype1_txt':'Attack_Type', 'target1':'Target', 'nkill':'Killed'
                   , 'nwound':'Wounded', 'weaptype1_txt':'Weapon_type',
                   'targtype1_txt':'Target_Type', 'gname':'Group'}, inplace=True)

# %% [markdown]
# ### Finding Null values
# #### Null values in columns

# %%
df.isnull().sum()
# Out:
# eventid            0
# Year               0
# Month              0
# Day                0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
perc_missing = (((df.isnull().sum()).sum())/df.size)*100
perc_missing
# Out:
# 56.481718962414206

# %% [markdown]
# **There are more than 50% values that are null, we need to clean the Dataset first.**

# %% [markdown]
# ## Creating dataframe with necessary columns only

# %%
df1 = df[['Year', 'Month', 'Day', 'Country', 'State', 'Region', 'city', 'latitude', 'longitude', 'Attack_Type', 'Killed',
         'Wounded', 'Group', 'Target', 'Target_Type', 'Weapon_type']]
df1.head(10)
# Out:
#    Year  Month  Day             Country       State  \
# 0  1970      7    2  Dominican Republic         NaN
# 1  1970      0    0              Mexico     Federal
# 2  1970      1    0         Philippines      Tarlac
# 3  1970      1    0              Greece      Attica
# 4  1970      1    0               Japan     Fukouka
# 5  1970      1    1       United States    Illinois
# 6  1970      1    2             Uruguay  Montevideo
# 7  1970      1    2       United States  California
# 8  1970      1    2       United States   Wisconsin
# 9  1970      1    3       United States   Wisconsin
#
#                         Region           city   latitude   longitude  \
# 0  Central America & Caribbean  Santo Domingo  18.456792  -69.951164
# 1                North America    Mexico city  19.371887  -99.086624
# 2               Southeast Asia        Unknown  15.478598  120.599741
# 3               Western Europe         Athens  37.997490   23.762728
# ...

# %% [markdown]
# **Unique Values in the columns**

# %%
for i in df1.columns:
    print(i, df1[i].nunique())
# Out:
# Year 47
# Month 13
# Day 32
# Country 205
# State 2854
# Region 12
# city 36674
# latitude 48322
# longitude 48039
# Attack_Type 9
# Killed 205
# Wounded 238
# Group 3537
# Target 86006
# Target_Type 22
# Weapon_type 12

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 16 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Year         181691 non-null  int64
#  1   Month        181691 non-null  int64
#  2   Day          181691 non-null  int64
#  3   Country      181691 non-null  object
#  4   State        181270 non-null  object
#  5   Region       181691 non-null  object
#  6   city         181257 non-null  object
#  7   latitude     177135 non-null  float64
#  8   longitude    177134 non-null  float64
#  9   Attack_Type  181691 non-null  object
#  10  Killed       171378 non-null  float64
#  11  Wounded      165380 non-null  float64
#  12  Group        181691 non-null  object
#  13  Target       181055 non-null  object
#  14  Target_Type  181691 non-null  object
#  15  Weapon_type  181691 non-null  object
# dtypes: float64(4), int64(3), object(9)
# memory usage: 22.2+ MB

# %%
df1['Wounded'] = df['Wounded'].fillna(0).astype(int)
df1['Killed'] = df['Killed'].fillna(0).astype(int)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 16 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Year         181691 non-null  int64
#  1   Month        181691 non-null  int64
#  2   Day          181691 non-null  int64
#  3   Country      181691 non-null  object
#  4   State        181270 non-null  object
#  5   Region       181691 non-null  object
#  6   city         181257 non-null  object
#  7   latitude     177135 non-null  float64
#  8   longitude    177134 non-null  float64
#  9   Attack_Type  181691 non-null  object
#  10  Killed       181691 non-null  int32
#  11  Wounded      181691 non-null  int32
#  12  Group        181691 non-null  object
#  13  Target       181055 non-null  object
#  14  Target_Type  181691 non-null  object
#  15  Weapon_type  181691 non-null  object
# dtypes: float64(2), int32(2), int64(3), object(9)
# memory usage: 20.8+ MB

# %% [markdown]
# **Cleaned Data**

# %%
df1
# Out:
#         Year  Month  Day             Country            State  \
# 0       1970      7    2  Dominican Republic              NaN
# 1       1970      0    0              Mexico          Federal
# 2       1970      1    0         Philippines           Tarlac
# 3       1970      1    0              Greece           Attica
# 4       1970      1    0               Japan          Fukouka
# ...      ...    ...  ...                 ...              ...
# 181686  2017     12   31             Somalia  Middle Shebelle
# 181687  2017     12   31               Syria         Lattakia
# 181688  2017     12   31         Philippines      Maguindanao
# 181689  2017     12   31               India          Manipur
# 181690  2017     12   31         Philippines      Maguindanao
#
#                              Region           city   latitude   longitude  \
# 0       Central America & Caribbean  Santo Domingo  18.456792  -69.951164
# ...

# %% [markdown]
# ## Univariate Analysis
# **The term univariate analysis refers to the analysis of one variable, prefix "uni" means "one".The purpose of univariate analysis is to understand the distribution of the values for a single variable.**

# %%
df1['Attack_Type'].value_counts()
# Out:
# Bombing/Explosion                      88255
# Armed Assault                          42669
# Assassination                          19312
# Hostage Taking (Kidnapping)            11158
# Facility/Infrastructure Attack         10356
# Unknown                                 7276
# Unarmed Assault                         1015
# Hostage Taking (Barricade Incident)      991
# Hijacking                                659
# Name: Attack_Type, dtype: int64

# %%
(df1['Attack_Type'].value_counts()/df1.shape[0])*100
# Out:
# Bombing/Explosion                      48.574228
# Armed Assault                          23.484377
# Assassination                          10.629035
# Hostage Taking (Kidnapping)             6.141196
# Facility/Infrastructure Attack          5.699787
# Unknown                                 4.004601
# Unarmed Assault                         0.558641
# Hostage Taking (Barricade Incident)     0.545432
# Hijacking                               0.362704
# Name: Attack_Type, dtype: float64

# %%
df1['Attack_Type'].value_counts().plot(kind='pie',title = 'Percentage of Attack Type Distribution', autopct='%1.2f%%', figsize=(15,15))
# Out:
# <AxesSubplot:title={'center':'Percentage of Attack Type Distribution'}, ylabel='Attack_Type'>

# %% [markdown]
# **Conclusion :** Highest number of attacks happend with Bombing/Explosion (48.57%) & Second highest by Armed Assaults (23.48%)

# %%
df1['Country'].value_counts()[:10]
# Out:
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Name: Country, dtype: int64

# %%
(df1['Country'].value_counts()[:10]/df1.shape[0])*100
# Out:
# Iraq              13.559285
# Pakistan           7.907932
# Afghanistan        7.006951
# India              6.582605
# Colombia           4.571498
# Philippines        3.802060
# Peru               3.355147
# El Salvador        2.928048
# United Kingdom     2.881265
# Turkey             2.362252
# Name: Country, dtype: float64

# %%
plt.figure(figsize=(10,10))
sns.barplot(df1['Country'].value_counts()[:10].index,df1['Country'].value_counts()[:10].values, palette = 'magma')
plt.style.use('ggplot')
plt.title('Top 10 Countries affected with Terrorism',fontsize=20)
plt.xlabel('Countries')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %%
# Top 10 Attack Targets

# %%
df1['Target_Type'].value_counts()[:10]
# Out:
# Private Citizens & Property       43511
# Military                          27984
# Police                            24506
# Government (General)              21283
# Business                          20669
# Transportation                     6799
# Utilities                          6023
# Unknown                            5898
# Religious Figures/Institutions     4440
# Educational Institution            4322
# Name: Target_Type, dtype: int64

# %%
plt.figure(figsize=(10,10))
sns.barplot(df1['Target_Type'].value_counts()[:10].index,df1['Target_Type'].value_counts()[:10].values, palette='gist_heat')
plt.title('Top 10 Attack Targets',fontsize=20)
plt.xlabel('Targets')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %%
plt.subplot(1,2,1)
# regions with most attacks
sns.barplot(df1['Region'].value_counts().head(15).index, df1['Region'].value_counts().head(15).values, palette='cubehelix' )
plt.title('Most Attacked Regions', fontsize=25)
plt.xlabel('Regions', fontsize=18)
plt.ylabel('Number of Attacks', fontsize=18)
plt.xticks(rotation=90)

plt.subplot(1,2,2)
# States with most attacks
sns.barplot(df1['State'].value_counts().head(15).index, df1['State'].value_counts().head(15).values, palette='gist_earth' )
plt.title('Most Attacked States', fontsize=25)
plt.xlabel('States', fontsize=18)
plt.ylabel('Number of Attacks', fontsize=18)
plt.xticks(rotation=90)



plt.gcf().set_size_inches(15,7)

# %%
df1['Weapon_type'].value_counts()
# Out:
# Explosives                                                                     92426
# Firearms                                                                       58524
# Unknown                                                                        15157
# Incendiary                                                                     11135
# Melee                                                                           3655
# Chemical                                                                         321
# Sabotage Equipment                                                               141
# Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)      136
# Other                                                                            114
# Biological                                                                        35
# Fake Weapons                                                                      33
# ...

# %%
((df1['Weapon_type'].value_counts()/df1['Weapon_type'].shape[0])*100).head()
# Out:
# Explosives    50.869883
# Firearms      32.210731
# Unknown        8.342185
# Incendiary     6.128537
# Melee          2.011657
# Name: Weapon_type, dtype: float64

# %%
plt.figure(figsize=(10,10))
sns.barplot(df1['Weapon_type'].value_counts().head().index,df1['Weapon_type'].value_counts().head().values)
plt.title('Top 5 used Weapons',fontsize=20)
plt.xlabel('Weapons used')
plt.ylabel('Number of Attacks')
plt.xticks(rotation=90)
plt.show()

# %%
# Number of attacks in each year

# %%
df1['Year'].value_counts().head(10)
# Out:
# 2014    16903
# 2015    14965
# 2016    13587
# 2013    12036
# 2017    10900
# 2012     8522
# 2011     5076
# 1992     5071
# 2010     4826
# 2008     4805
# Name: Year, dtype: int64

# %%
plt.subplot(2,1,1)
#plt.figure(figsize=(10,10))
sns.barplot(df1['Year'].value_counts().index,df1['Year'].value_counts().values, palette='twilight_shifted')
plt.title('Attacks per Year',fontsize=20)
plt.xlabel('Attack Year', fontsize=20)
plt.ylabel('Number of Attacks', fontsize=20)
plt.xticks(rotation=90)
plt.gcf().set_size_inches(10,20)

plt.figure(figsize=(10,10))
sns.barplot(df1.groupby(['Year'])['Killed'].sum().index,df1.groupby(['Year'])['Killed'].sum().values, palette='turbo')
#df1.groupby(['Year'])['Killed'].sum().plot(kind='bar', cmap='summer')
plt.title('Deaths per year',fontsize=20)
plt.xlabel('Attack Year', fontsize=20)
plt.ylabel('Number of Deaths', fontsize=20)
plt.xticks(rotation=90)

plt.gcf().set_size_inches(10,10)

# %%
plt.figure(figsize=(10,10))
sns.barplot(df1.groupby(['Year'])['Killed'].sum().index,df1.groupby(['Year'])['Killed'].sum().values, palette='viridis')
#df1.groupby(['Year'])['Killed'].sum().plot(kind='bar', cmap='summer')
plt.title('Deaths per year',fontsize=20)
plt.xlabel('Attack Year', fontsize=20)
plt.ylabel('Number of Deaths', fontsize=20)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.barplot(df1['Group'].value_counts()[1:11].values,df1['Group'].value_counts()[1:11].index, palette='bone')
plt.title('Top 10 Terrorist Organizations with Highest Terror Attacks', fontsize = 15)
plt.xlabel('Number of Attacks',fontsize=15)
plt.ylabel('Terrorist Groups',fontsize=15)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.kdeplot(df1['Year'],hue = df1['Region'])
plt.title('Terrorist Activities by Region in each Year',fontsize=20)
plt.xlabel('Year', fontsize=20)
plt.ylabel('Number of Attacks', fontsize=20)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Bivariate Analysis

# %%
# Region with most wounded people 
plt.subplot(1,2,1)
sns.barplot(df1.groupby(['Region'])['Wounded'].sum().sort_values(ascending=False).index,
            df1.groupby(['Region'])['Wounded'].sum().sort_values(ascending=False).values,
           palette = 'bone')
plt.title('Region wise people Wounded', fontsize=20)
plt.xlabel('Region', fontsize=20)
plt.ylabel('People Wounded', fontsize=20)
plt.xticks(rotation=90)


# Region with most killed people
plt.subplot(1,2,2)
sns.barplot(df1.groupby(['Region'])['Killed'].sum().sort_values(ascending=False).index,
            df1.groupby(['Region'])['Killed'].sum().sort_values(ascending=False).values,
           palette = 'bone')
plt.title('Region wise people Killed', fontsize=20)
plt.xlabel('Region', fontsize=20)
plt.ylabel('People Killed', fontsize=20)
plt.xticks(rotation=90)

plt.gcf().set_size_inches(15,7)

# %%
# Region with most wounded people 
plt.subplot(1,2,1)
sns.barplot(df1.groupby(['Country'])['Wounded'].sum().sort_values(ascending=False).head(10).index,
            df1.groupby(['Country'])['Wounded'].sum().sort_values(ascending=False).head(10).values,
           palette = 'hot')
plt.title('Country wise people Wounded', fontsize=20)
plt.xlabel('Country', fontsize=20)
plt.ylabel('People Wounded', fontsize=20)
plt.xticks(rotation=90)


# Region with most killed people
plt.subplot(1,2,2)
sns.barplot(df1.groupby(['Country'])['Killed'].sum().sort_values(ascending=False).head(10).index,
            df1.groupby(['Country'])['Killed'].sum().sort_values(ascending=False).head(10).values,
           palette = 'hot')
plt.title('Country wise people Killed', fontsize=20)
plt.xlabel('Country', fontsize=20)
plt.ylabel('People Killed', fontsize=20)
plt.xticks(rotation=90)

plt.gcf().set_size_inches(15,7)

# %%
df1_tal=df1[df1.Group=='Taliban']

# %%
# Terror attacks by Taliban over the years
plt.figure(figsize=(13,7))
sns.barplot(df1_tal['Year'].value_counts().index,df1_tal['Year'].value_counts().values, palette='viridis')
plt.title('Terror attacks by Taliban over the years', fontsize = 15)
plt.xlabel('Year',fontsize=15)
plt.ylabel('Number of Attacks',fontsize=15)
plt.xticks(rotation=90)
plt.show()

# %%
# cretaing new dataframe for the year 2014, since it has the highest number of attacks
df1_2014 = df1[df1.Year==2014]

# %%
# regions attacked the most in 2014
plt.subplot(1,2,1)
sns.barplot(df1_2014['Region'].value_counts().index, df1_2014['Region'].value_counts().values, palette='cubehelix' )
plt.title('Most Attacked Regions in 2014', fontsize=20)
plt.xlabel('Regions', fontsize=18)
plt.ylabel('Number of Attacks', fontsize=18)
plt.xticks(rotation=90)

# Top 10 Countries attacked in 2014
plt.subplot(1,2,2)
sns.barplot(df1_2014['Country'].value_counts().head(10).index, df1_2014['Country'].value_counts().head(10).values, palette='gist_earth' )
plt.title('Top 10 Countries attacked in 2014', fontsize=20)
plt.xlabel('Country', fontsize=18)
plt.ylabel('Number of Attacks', fontsize=18)
plt.xticks(rotation=90)



plt.gcf().set_size_inches(15,7)

# %%
# Coyntries with most Killed people in 2014
plt.subplot(1,2,1)
sns.barplot(df1_2014.groupby(['Country'])['Killed'].sum().sort_values(ascending=False).head(10).index,
            df1_2014.groupby(['Country'])['Killed'].sum().sort_values(ascending=False).head(10).values,
           palette = 'magma')
plt.title('Top 10 Countries with max people killed in 2014', fontsize=15)
plt.xlabel('Country', fontsize=20)
plt.ylabel('People Killed', fontsize=20)
plt.xticks(rotation=90)


# Countries with most wounded people in 2014
plt.subplot(1,2,2)
sns.barplot(df1_2014.groupby(['Country'])['Wounded'].sum().sort_values(ascending=False).head(10).index,
            df1_2014.groupby(['Country'])['Wounded'].sum().sort_values(ascending=False).head(10).values,
           palette = 'magma')
plt.title('Top 10 Countries with max people wounded in 2014', fontsize=15)
plt.xlabel('Country', fontsize=20)
plt.ylabel('People Wounded', fontsize=20)
plt.xticks(rotation=90)

plt.gcf().set_size_inches(15,7)

# %% [markdown]
# ## Conclusion
# **After performing the Exploratory Data Analysis we get the following insights from the data:**
#
# - Private Citizens and Property were attacked most followed by Military, Police, Government and so on.
# - Middle East & North Africa was most affected among the top affected region. Most of the people in this region were either wounded or killed.
# - Iraq was the country which was most affected by terror attacks and had maximum number of killed and wounded people.
# - The State and City that was most affected was Baghdad
# - In the last decade 2014 had most number of terror attacks. That was around 16500 attacks during this year which means on average 45 attacks per day.
# - The most common attack type was Bombing/Explosion.
# - Explosives have been consistently the most popular weapon of choice for terrorists.
# - Taliban became more active since 2012 and they are responsible for the most of the terror attacks
